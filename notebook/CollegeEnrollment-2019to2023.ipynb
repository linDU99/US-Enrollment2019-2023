# %% [markdown]
# ### U.S. College Enrollment Trends: 2019 - 2023
# ##### Purposes:
# - Create an interactive dash application from an explanatory perspective with Plotly Dash.
# - Explore enrollment trends of US degree-granting institutions (colleges, universities, and technical and vocational institutions).
# - Display enrollment changes across groups:
#     - Education level: Undergraduate (UG) vs. Graduate (GR)
#     - Gender: Women vs. Men
#     - Study status: Full-Time (FT) vs. Part-Time (PT)
#
# ##### Data:
# The enrollment data are from the Integrated Postsecondary Education Data System (IPEDS) provided by the U.S. National Center for Education Statistics (NCES). Source: https://nces.ed.gov/ipeds/summarytables
# - Limited to all Title IV degree-granting institutions in the U.S.: N ≥ 3838
# - The numbers of enrollment are summary data of all institutes included.
# - The enrollments are the fall terms of 2019 to 2023.
# - Enrollment App: The default model includes the enrollment of all groups. Groups' data can be selected by clicking the checkbox.
#
# **GitHub repository link:** https://github.com/linDU99/US-Enrollment2019-2023.git
# #

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import dash
from dash import Dash, dcc, html, Output, Input, dash_table, callback  # dcc - Dash Core Components
pio.renderers.default = "notebook_connected"

# %%
# df1: Read the datasets
df1_EnrolByGroups = pd.read_csv("Data-1EnrollmentBy3Groups.csv")

# Set display width for better readability  
pd.set_option('display.width', 600)   

# # Information of the 1st dataset
# print("Dataset 1: Enrollment by Groups " + str(df1_EnrolByGroups.shape))
print(df1_EnrolByGroups.head(), "\n")
# display(df1_EnrolByGroups.info())

# df1_EnrolByGroups.isnull().sum()  # Check for missing values
# df1_EnrolByGroups.dropna(inplace=True)  # Drop rows with missing values
# Out:
#    Year Education_Level Gender Study_Status Enrollment
# 0  2019  Undergraduates    Men    Full-Time  4,543,556
# 1  2020  Undergraduates    Men    Full-Time  4,265,661
# 2  2021  Undergraduates    Men    Full-Time  4,139,458
# 3  2022  Undergraduates    Men    Full-Time  4,139,295
# 4  2023  Undergraduates    Men    Full-Time  4,266,721

# %%
# Convert the "Enrollment" column to integer
# Note: The "Enrollment" column have commas. Values like "4,543,556" are stored as strings, , not numbers. 
df1_EnrolByGroups["Enrollment"] = (
    df1_EnrolByGroups["Enrollment"]
    .replace({",": ""}, regex=True)   # Remove commas
    .astype(int))                     # Convert to integer

print(df1_EnrolByGroups.head(), "\n")

print(df1_EnrolByGroups["Year"].unique())  # Data type - integer! Maybe need to convert to 'string'
print(df1_EnrolByGroups["Education_Level"].unique())
print(df1_EnrolByGroups["Gender"].unique())
# print(df1_EnrolByGroups["Study_Status"].unique(),"\n")

df1_EnrolByGroups["Year"] = df1_EnrolByGroups["Year"].astype(str)  # Convert to string for plotting
print(df1_EnrolByGroups["Year"].unique()) 

# Statistics of Enrollment
enrollment_stats = df1_EnrolByGroups.describe()
enrollment_stats = enrollment_stats.transpose()  # Transpose for better readability
print("\nEnrollment Statistics:\n", enrollment_stats, "\n")
# Out:
#    Year Education_Level Gender Study_Status  Enrollment
# 0  2019  Undergraduates    Men    Full-Time     4543556
# 1  2020  Undergraduates    Men    Full-Time     4265661
# 2  2021  Undergraduates    Men    Full-Time     4139458
# 3  2022  Undergraduates    Men    Full-Time     4139295
# 4  2023  Undergraduates    Men    Full-Time     4266721
#
# ['2019' '2020' '2021' '2022' '2023']
# ['Undergraduates' 'Graduates']
# ['Men' 'Women']
# ['2019' '2020' '2021' '2022' '2023']
#
# Enrollment Statistics:
#              count         mean           std       min        25%        50%         75%        max
# Enrollment   40.0  2373485.625  1.787899e+06  474493.0  824769.75  1749188.5  3841212.75  5666237.0

# %%
# df1: 1.Enrollment by Year and Education LeveL
enrollment_stats = df1_EnrolByGroups.groupby(['Year', 'Education_Level'])['Enrollment'].sum().reset_index()
# Sort df in descending order by 'Education_Level'
df_edu_sorted1 = enrollment_stats.sort_values(by="Education_Level", ascending=False)
print(enrollment_stats, "\n")
print(df_edu_sorted1)

# Bar plot for using Plotly Express
fig = px.bar(df_edu_sorted1,
             x='Year', y='Enrollment', 
             color='Education_Level', 
             title='Enrollment by Year and Education Level',
             labels={'Enrollment': 'Total Enrollment', 'Year': 'Academic Year'},
             barmode='group')
# Update layout for better visualization
fig.update_layout(
    xaxis_title='Academic Year',
    yaxis_title='Total Enrollment',
    legend_title='Education Level',
    title_x=0.5,  # Center the title
    height=350, width=600
)
fig.show()

# 2. Enrollment by Year, Education Level, and study status
enrollment_stats_study_status = df1_EnrolByGroups.groupby(['Year', 'Education_Level', 'Study_Status'])['Enrollment'].sum().reset_index()
# Sort df in descending order by 'Education_Level' and 'Study_Status'
df_edu_sorted2 = enrollment_stats_study_status.sort_values(by=["Education_Level", "Study_Status"], ascending=[False, True])

# Bar plot for  using Plotly Express
fig_study_status = px.bar(df_edu_sorted2, 
                          x='Year', y='Enrollment',
                          color='Study_Status', 
                          facet_col='Education_Level',
                          title='Enrollment by Year, Education Level, and Study Status',
                          labels={'Enrollment': 'Total Enrollment', 'Year': 'Academic Year'},
                          barmode='group')
# Update layout for better visualization
fig_study_status.update_layout(
    xaxis_title='Academic Year',
    yaxis_title='Total Enrollment',
    legend_title='Study Status',
    title_x=0.5,  # Center the title
    height=350, width=700    
)
fig_study_status.show()
# Out:
#    Year Education_Level  Enrollment
# 0  2019       Graduates     3072639
# 1  2019  Undergraduates    16557539
# 2  2020       Graduates     3142851
# 3  2020  Undergraduates    15884559
# 4  2021       Graduates     3211199
# 5  2021  Undergraduates    15447557
# 6  2022       Graduates     3183631
# 7  2022  Undergraduates    15399866
# 8  2023       Graduates     3213822
# 9  2023  Undergraduates    15825762
#
#    Year Education_Level  Enrollment
# 1  2019  Undergraduates    16557539
# 3  2020  Undergraduates    15884559
# 5  2021  Undergraduates    15447557
# 7  2022  Undergraduates    15399866
# 9  2023  Undergraduates    15825762
# 0  2019       Graduates     3072639
# 2  2020       Graduates     3142851
# 4  2021       Graduates     3211199
# 6  2022       Graduates     3183631
# 8  2023       Graduates     3213822
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="b82e8ae3-fd28-437c-8d79-4408e7d71416" class="plotly-graph-div" style="height:350px; width:600px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b82e8ae3-fd28-437c-8d79-4408e7d71416")) {                    Plotly.newPlot(                        "b82e8ae3-fd28-437c-8d79-4408e7d71416",                        [{"alignmentgroup":"True","hovertemplate":"Education_Level=Undergraduates\u003cbr\u003eAcademic Year=%{x}\u003cbr\u003eTotal Enrollment=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Undergraduates","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Undergraduates","offsetgroup":"Undergraduates","orientation":"v","showlegend":true,"textposition":"auto","x":["2019","2020","2021","2022","2023"],"xaxis":"x","y":{"dtype":"i4","bdata":"46X8AA9h8gAFtusAuvvqAGJ78QA="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Education_Level=Graduates\u003cbr\u003eAcademic Year=%{x}\u003cbr\u003eTotal Enrollment=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Graduates","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Graduates","offsetgroup":"Graduates","orientation":"v","showlegend":true,"textposition":"auto","x":["2019","2020","2021","2022","2023"],"xaxis":"x","y":{"dtype":"i4","bdata":"f+IuAMP0LwC\u002f\u002fzAAD5QwAP4JMQA="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"colo ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="888fe1a9-8168-4625-be19-f5004a7181b1" class="plotly-graph-div" style="height:350px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("888fe1a9-8168-4625-be19-f5004a7181b1")) {                    Plotly.newPlot(                        "888fe1a9-8168-4625-be19-f5004a7181b1",                        [{"alignmentgroup":"True","hovertemplate":"Study_Status=Full-Time\u003cbr\u003eEducation_Level=Undergraduates\u003cbr\u003eAcademic Year=%{x}\u003cbr\u003eTotal Enrollment=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Full-Time","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Full-Time","offsetgroup":"Full-Time","orientation":"v","showlegend":true,"textposition":"auto","x":["2019","2020","2021","2022","2023"],"xaxis":"x","y":{"dtype":"i4","bdata":"AcqbAMIxlgB96ZAAFM2PABmjkwA="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Study_Status=Full-Time\u003cbr\u003eEducation_Level=Graduates\u003cbr\u003eAcademic Year=%{x}\u003cbr\u003eTotal Enrollment=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Full-Time","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Full-Time","offsetgroup":"Full-Time","orientation":"v","showlegend":false,"textposition":"auto","x":["2019","2020","2021","2022","2023"],"xaxis":"x2","y":{"dtype":"i4","bdata":"7J4aAMTzGgAK6hsAIm4cAIwHHQA="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Study_Status=Part-Time\u003cbr\u003eEducation_Level=Undergraduates\u003cbr\u003eAcademic Year=%{x}\u003cbr\u003eTotal Enrollment=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Part-Time","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Part-Time","offsetgroup":"Part-Time","orientation":"v","showlegend":true,"textposition":"auto","x":["2019","2020","2021","2022","2023"],"xaxis":"x","y":{"dtype":"i4","bdata":"4ttgAE0vXACIzFoApi5bAEnYXQA="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Study_Status=Part-Time\u003cbr\u003eEducation_Level=Graduates\u003cbr\u003eAcademic Year=%{x}\u003cbr\u003eTotal Enrollment=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Part-Time","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Part-Time","offsetgroup":"Part-Time","orientation":"v","showlegend":false,"textposition":"auto","x":["2019","2020","2021","2022","2023"],"xaxis":"x2","y":{"dtype":"i4","bdata":"k0MUAP8AFQC1FRUA7SUUAHICFAA="},"yaxis":"y2","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0 ...

# %%
# 3. Enrollment by Year, Education Level and Gender
enrol_by_edu_gender = df1_EnrolByGroups.groupby(['Year', 'Education_Level', 'Gender'])['Enrollment'].sum().reset_index()
# Sort df in descending order by 'Education_Level' and 'Gender'
df_edu_sorted3 = enrol_by_edu_gender.sort_values(by=["Education_Level", "Gender"], ascending=[False, True])
# Bar plot for using Plotly Express
fig3_gender = px.bar(df_edu_sorted3,
                    x='Year', y='Enrollment',
                    color = "Gender",
                    facet_col='Education_Level',
                    title='Enrollment by Year, Education Level, and Gender',
                    labels={'Enrollment': 'Total Enrollment', 'Year': 'Academic Year'},
                    barmode='group')
# Update layout for better visualization
fig3_gender.update_layout(
    xaxis_title='Academic Year',
    yaxis_title='Total Enrollment',
    legend_title='Gender',
    title_x=0.5,  # Center the title
    height=400, width=1000
)
fig3_gender.show()


# 4. Percentage of enrollment by gender, also by year and education level
# Step 1: Calculate total enrollment per year and education level
df_total = df1_EnrolByGroups.groupby(['Year', 'Education_Level'])['Enrollment'].sum().reset_index()
df_total = df_total.rename(columns={'Enrollment': 'Total'})

# Step 2: Calculate enrollment per gender per year and education level
df_gender = df1_EnrolByGroups.groupby(['Year', 'Education_Level', 'Gender'])['Enrollment'].sum().reset_index()
# Sort df in descending order by 'Education_Level'
df_gender_sorted = df_gender.sort_values(by=["Education_Level", "Gender"], ascending=[False, True])

# Step 3: Merge to compute percentages
df_merged = pd.merge(df_gender_sorted, df_total, on=['Year', 'Education_Level'])
df_merged['Percentage'] = (df_merged['Enrollment'] / df_merged['Total']) * 100

# Step 4: Create line chart using Plotly Express
fig4_gender_pct = px.line(
    df_merged,
    x='Year',
    y='Percentage',
    color='Gender',
    line_dash='Education_Level',
    markers=True,
    facet_col='Education_Level',
    title='Percentage of Enrollment by Gender',
    labels={'Percentage': 'Enrollment Percentage (%)'}
)
fig4_gender_pct.update_layout(
    template='plotly_white',
    yaxis=dict(range=[0, 100]),
    legend_title='Gender',
    title_x=0.5,  # Center the title
    height=400, width=1000
)
fig4_gender_pct.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="89d83a3f-0edd-4d01-a410-00b9f4c3b174" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("89d83a3f-0edd-4d01-a410-00b9f4c3b174")) {                    Plotly.newPlot(                        "89d83a3f-0edd-4d01-a410-00b9f4c3b174",                        [{"alignmentgroup":"True","hovertemplate":"Gender=Men\u003cbr\u003eEducation_Level=Undergraduates\u003cbr\u003eAcademic Year=%{x}\u003cbr\u003eTotal Enrollment=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Men","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Men","offsetgroup":"Men","orientation":"v","showlegend":true,"textposition":"auto","x":["2019","2020","2021","2022","2023"],"xaxis":"x","y":{"dtype":"i4","bdata":"ihdtAIezZQDni2MAV1pkAB\u002fQZwA="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Gender=Men\u003cbr\u003eEducation_Level=Graduates\u003cbr\u003eAcademic Year=%{x}\u003cbr\u003eTotal Enrollment=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Men","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Men","offsetgroup":"Men","orientation":"v","showlegend":false,"textposition":"auto","x":["2019","2020","2021","2022","2023"],"xaxis":"x2","y":{"dtype":"i4","bdata":"54cSAGKdEgBT+xIA9vESAKVFEwA="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Gender=Women\u003cbr\u003eEducation_Level=Undergraduates\u003cbr\u003eAcademic Year=%{x}\u003cbr\u003eTotal Enrollment=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Women","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Women","offsetgroup":"Women","orientation":"v","showlegend":true,"textposition":"auto","x":["2019","2020","2021","2022","2023"],"xaxis":"x","y":{"dtype":"i4","bdata":"WY6PAIitjAAeKogAY6GGAEOriQA="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Gender=Women\u003cbr\u003eEducation_Level=Graduates\u003cbr\u003eAcademic Year=%{x}\u003cbr\u003eTotal Enrollment=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Women","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Women","offsetgroup":"Women","orientation":"v","showlegend":false,"textposition":"auto","x":["2019","2020","2021","2022","2023"],"xaxis":"x2","y":{"dtype":"i4","bdata":"mFocAGFXHQBsBB4AGaIdAFnEHQA="},"yaxis":"y2","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale": ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="0562e78c-1c16-4c17-a41c-446cb37f74cd" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0562e78c-1c16-4c17-a41c-446cb37f74cd")) {                    Plotly.newPlot(                        "0562e78c-1c16-4c17-a41c-446cb37f74cd",                        [{"hovertemplate":"Gender=Men\u003cbr\u003eEducation_Level=Undergraduates\u003cbr\u003eYear=%{x}\u003cbr\u003eEnrollment Percentage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Men, Undergraduates","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Men, Undergraduates","orientation":"v","showlegend":true,"x":["2019","2020","2021","2022","2023"],"xaxis":"x","y":{"dtype":"f8","bdata":"bgkvX\u002feWRUDgsois0\u002fpEQCA5oFTAHUVA2MvgBWtaRUB4C26ltn5FQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Gender=Men\u003cbr\u003eEducation_Level=Graduates\u003cbr\u003eYear=%{x}\u003cbr\u003eEnrollment Percentage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Men, Graduates","line":{"color":"#636efa","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Men, Graduates","orientation":"v","showlegend":true,"x":["2019","2020","2021","2022","2023"],"xaxis":"x2","y":{"dtype":"f8","bdata":"yGrPMxzDQ0Dix4kGfGhDQPh3HS+YXkNArXB\u002fJeV\u002fQ0CaEBT7UqZDQA=="},"yaxis":"y2","type":"scatter"},{"hovertemplate":"Gender=Women\u003cbr\u003eEducation_Level=Undergraduates\u003cbr\u003eYear=%{x}\u003cbr\u003eEnrollment Percentage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Women, Undergraduates","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Women, Undergraduates","orientation":"v","showlegend":true,"x":["2019","2020","2021","2022","2023"],"xaxis":"x","y":{"dtype":"f8","bdata":"kvbQoAhpTEAfTXdTLAVNQN\u002fGX6s\u002f4kxAKDQf+pSlTECH9JFaSYFMQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Gender=Women\u003cbr\u003eEducation_Level=Graduates\u003cbr\u003eYear=%{x}\u003cbr\u003eEnrollment Percentage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Women, Graduates","line":{"color":"#EF553B","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Women, Graduates","orientation":"v","showlegend":true,"x":["2019","2020","2021","2022","2023"],"xaxis":"x2","y":{"dtype":"f8","bdata":"OZUwzOM8TkAeOHb5g5dOQAiI4tBnoU5AU4+A2hqATkBm7+sErVlOQA=="},"yaxis":"y2","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0 ...

# %%
# df2: Total enrollment by year
df2_total = pd.read_csv("Data-2TotalEnrollment.csv")
print(df2_total.head())

# Note: The values of Enrollment (with commas) are stored as 'strings', althought the csv file saves them as numbers.
# Convert their data type to integer when needed for analysis!
# Out:
#    Year N_Institutes Total-Enrollment Undergraduates (UG) Total   UG-Women UG-Women %     UG-Men UG-Men % Graduates (GR) Total   GR-Women GR-Women %     GR-Men GR-Men % Women-Total (UG + GR) Men-Total (UG + GR) Difference (W - M)
# 0  2019        3,838       19,630,178                16,557,539  9,408,089     56.82%  7,149,450   43.18%            3,072,639  1,858,200     60.48%  1,214,439   39.52%            11,266,289           8,363,889          2,902,400
# 1  2020        3,894       19,027,410                15,884,559  9,219,464     58.04%  6,665,095   41.96%            3,142,851  1,922,913     61.18%  1,219,938   38.82%            11,142,377           7,885,033          3,257,344
# 2  2021        3,893       18,658,756                15,447,557  8,923,678     57.77%  6,523,879   42.23%            3,211,199  1,967,212     61.26%  1,243,987   38.74%            10,890,890           7,767,866          3,123,024
# 3  2022        3,928       18,583,497                15,399,866  8,823,139     57.29%  6,576,727   42.71%            3,183,631  1,942,041     61.00%  1,241,590   39.00%            10,765,180           7,818,317          2,946,863
# 4  2023        3,947       19,039,584                15,825,762  9,022,275     57.01%  6,803,487   42.99%            3,213,822  1,950,809     60.70%  1,263,013   39.30%            10,973,084           8,066,500          2,906,584

# %%
# enrollment_dash_app.py

df1 = df1_EnrolByGroups.copy()

# Initialize app
app = dash.Dash(__name__)
app.title = "U.S. College Enrollment Trends"

# App Layout
app.layout = html.Div([
    html.H1("U.S. College Enrollment Trends 2019 - 2023", style={"color": "#1f77b4",'textAlign':'center'}),
    html.P("Display enrollment changes of U.S. degree-granting institutes over the years \
        by education level, gender, and study status.", style={'textAlign':'center','fontSize': 20}),
    html.P("Data source: The Integrated Postsecondary Education Data System (IPEDS) of the National Center for \
        Education Statistics (NCES)", style={"marginLeft": '248px', "fontSize": 15, "fontStyle": "italic"}),

    html.Hr(),  # Section divider for selection filters
    html.Div([
        html.Div([
            html.Label("Year Selection:", style={"color": 'darkblue', 'fontSize': 14, 'fontWeight': 'bold', 
                        "marginLeft": '500px', "marginRight": '8px'}),
            dcc.Checklist(
                ['2019', '2020', '2021', '2022', '2023'],  # Strings
                ['2019', '2020', '2021', '2022', '2023'],  # Default to all years
                inline=True,
                id="year-checklist")
        ], style={"display": 'flex', "alignItems": 'center', "color": 'darkblue'})  
    ], style={"width": "100%", "textAlign": "left", "padding": "10px"}),  #"justifyContent": "center"

    html.Div([
        html.Div([
            html.Label("Gender: ", style={"color": 'darkblue', 'fontSize': 14, 'fontWeight': 'bold', 
                        "marginLeft": '500px', "marginRight": '8px'}),
            dcc.Checklist(
                ['Women', 'Men'],
                ['Women', 'Men'],  # Default 
                inline=True,
                id="gender-checklist")
        ], style={"display": 'flex', "alignItems": 'left', 'fontSize': 14,})
    ], style={"width": "100%", "textAlign": "left", "padding": "10px"}), 

    html.Div([
        html.Div([
            html.Label("Study Status: ", style={"color": 'darkblue', 'fontSize': 14, 'fontWeight': 'bold', 
                        "marginLeft": '500px', "marginRight": '8px'}),
            dcc.Checklist(
                ['Full-Time', 'Part-Time'],
                ['Full-Time', 'Part-Time'],  # Default 
                inline=True,
                id="status-checklist")
        ], style={"display": 'flex', "alignItems": 'left', 'fontSize': 14,})
    ], style={ "textAlign": "left", "padding": "10px"}),
    
    # Secetion of plots
    html.Hr(style={"marginLeft": '450px', "marginRight": '520px'}),
    html.Div(id="multi-plot-container"),  # Container for all plots

    # Section of table 
    html.Hr(style={"marginLeft": '430px', "marginRight": '430px'}),
    # html.Hr(),
    html.H3("Summary Table: Total Enrollment by Education Level and Gender", style={"textAlign": "center"}),

    dash_table.DataTable(
        id='summary-table',
        columns=[{"name": i, "id": i} for i in df2_total.columns],
        data=df2_total.to_dict("records"),
        style_table={"overflowX": "auto", "margin": "2px"},
        style_cell={"textAlign": "center", "padding": "2px", "fontFamily": "Arial", "fontSize": 11},
        style_header={"backgroundColor": "lightgrey", "fontWeight": "bold"}
    ), 
],style={"marginBottom": "40px"})

@app.callback(
    Output("multi-plot-container", "children"),
    Input("year-checklist", "value"),
    Input("gender-checklist", "value"),
    Input("status-checklist", "value")
)
def update_graphs(selected_years, selected_gender, selected_status):
    # Step 1: Filter df1
    filtered_df = df1[
        df1["Year"].isin(selected_years) &
        df1["Gender"].isin(selected_gender) &
        df1["Study_Status"].isin(selected_status)
    ]

    plots = []
    final_line_figs = []

    for level in ["Undergraduates", "Graduates"]:
        df_sub = filtered_df[filtered_df["Education_Level"] == level]

        # Step 2: Group data
        data1 = df_sub.groupby("Year")["Enrollment"].sum().reset_index()
        data2 = (df_sub.groupby(["Year", "Gender"])["Enrollment"]
            .sum().reset_index())
        # Percentage of women by year
        total_by_year = data2.groupby("Year")["Enrollment"].sum().reset_index(name="Total")
        women_by_year = data2[data2["Gender"] == "Women"].groupby("Year")["Enrollment"].sum().reset_index(name="Women")
        data3 = pd.merge(total_by_year, women_by_year, on="Year", how="left")
        data3["Pct_Women"] = 100 * data3["Women"] / data3["Total"]

        # Step 3: Create line plot
        line_fig = px.line(
            data1,
            x="Year",
            y="Enrollment",
            markers=True,
            title=f"{level} - Total Enrollment Over Years",
            text="Enrollment" # value to be used as number label
        )
        line_fig.update_traces(
            mode='lines+markers+text',      # ensure text is shown
            textposition='top center',      # adjust if needed (try bottom too)
            texttemplate='%{text:,}',       # format with comma
            textfont=dict(size=10)
        )
        # Calculate y-axis range with padding
        y_min = data1["Enrollment"].min() * 0.98
        y_max = data1["Enrollment"].max() * 1.03

        line_fig.update_layout(
            template="plotly_white",
            width=700, height=350,
            margin=dict(t=40, l=100),
            yaxis=dict(range=[y_min, y_max]),  # Set y-axis range
        )

        # Step 4: Create bar plot
        bar_fig = px.bar(
            data2,
            x="Year",
            y="Enrollment",
            color="Gender",
            barmode="group",
            title=f"{level} - Enrollment by Gender"
        )
        bar_fig.update_layout(
            template="plotly_white",
            width=600, height=350,
            margin=dict(t=40)
        )

        # Step 5: Create line plot - Percentage
        line_fig2_w = px.line(
            data3,
            x="Year",
            y="Pct_Women",
            markers=True,
            title=f"{level} - % Women Enrollment by Year",
            text="Pct_Women"  # value to be used as percentage label
        )
        line_fig2_w.update_traces(
            mode='lines+markers+text',      # ensure text is shown
            textposition='top center',      # adjust if needed (try bottom too)
            texttemplate='%{text:.1f}%',     # format as percentage with one decimal
            textfont=dict(size=10)
        )
        line_fig2_w.update_layout(
            yaxis=dict(range=[50, 66]),  # Set y-axis range for percentage
            yaxis_title="Percentage of women (%)")
        final_line_figs.append(line_fig2_w)  # Collect for final display

        # Step 6: Add both plots side by side in one row
        row1 = html.Div([
            dcc.Graph(figure=line_fig, style={"display": "inline-block", "width": "48%"}),
            dcc.Graph(figure=bar_fig, style={"display": "inline-block", "width": "48%"})
        ], style={"display": "flex", "justifyContent": "space-between", "marginBottom": "30px"})

        plots.append(row1)

    # Add a section title or horizontal line before percentage plots
    plots.append(html.Hr())
    plots.append(html.H3("Percentage of Female Students Over Years", style={"textAlign": "center", "color": "darkblue"}))

    # Step 7: Callback for percentage line plots
    row_final = html.Div([
        dcc.Graph(figure=final_line_figs[0], style={"display": "inline-block", "width": "48%"}),
        dcc.Graph(figure=final_line_figs[1], style={"display": "inline-block", "width": "48%"})
    ], style={"display": "flex", "justifyContent": "space-between", "marginBottom": "40px"})

    plots.append(row_final)

    # Step 8: Return all rows (4+2 plots)
    return plots

# Run App
if __name__ == "__main__":
    app.run(debug=True)  # Use debug=True for development
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# #### Summary of U.S. College Enrollment 2019 - 2023
# - **Undergraduates:** Overall enrollment decreased continuously from Fall 2019 to Fall 2022. In Fall 2023, enrollment rebounded to approximately the 2020 level.
# - **Graduates:** The total enrollment increased consistently from Fall 2019 to Fall 2021. Since then, it has fluctuated around 3.2 million students.
# - **By Gender:** More than 57% of undergraduates and approximately 61% of graduates were female. Across all institutions (n ≥ 3,838), female enrollment exceeded male enrollment by at least 2.9 million students.
# - **By study status:** Overall, more than 60% of enrolled students were full-time.
